# %% [markdown]
# # Feature Selection
# ![types](feature-selection-techniques-in-machine-learning2.png)

# %% [markdown]
# ## Filter methods
# ![types](feature-selection-techniques-in-machine-learning4.png)

# %% [markdown]
# #### Information Gain

# %%
import numpy as np 
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
df=sns.load_dataset('iris')
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
from sklearn.feature_selection import mutual_info_classif

# %%
X=df.drop('species',axis=1)
y=df.species
importance=mutual_info_classif(X,y)
fi=pd.Series(importance,index=df.columns[0:-1])
fi.plot(kind='barh')
plt.show()

# %% [markdown]
# ### Chi-square

# %%
from sklearn.feature_selection import chi2,SelectKBest,f_classif

# %%
chi_f=SelectKBest(chi2,k=3)

# %%
pd.DataFrame(chi_f.fit_transform(X,y))
# Out:
#        0    1    2
# 0    5.1  1.4  0.2
# 1    4.9  1.4  0.2
# 2    4.7  1.3  0.2
# 3    4.6  1.5  0.2
# 4    5.0  1.4  0.2
# ..   ...  ...  ...
# 145  6.7  5.2  2.3
# 146  6.3  5.0  1.9
# 147  6.5  5.2  2.0
# 148  6.2  5.4  2.3
# 149  5.9  5.1  1.8
#
# [150 rows x 3 columns]

# %% [markdown]
# ### Correlation method

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder().fit(df.species)

# %%
df['species']=le.transform(df.species)

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ### Anova test

# %%
from sklearn.feature_selection import SelectKBest,f_classif
anova_f=SelectKBest(f_classif,k=3)

# %%
pd.DataFrame(anova_f.fit_transform(X,y))
# Out:
#        0    1    2
# 0    5.1  1.4  0.2
# 1    4.9  1.4  0.2
# 2    4.7  1.3  0.2
# 3    4.6  1.5  0.2
# 4    5.0  1.4  0.2
# ..   ...  ...  ...
# 145  6.7  5.2  2.3
# 146  6.3  5.0  1.9
# 147  6.5  5.2  2.0
# 148  6.2  5.4  2.3
# 149  5.9  5.1  1.8
#
# [150 rows x 3 columns]

# %% [markdown]
# ## Wrapper methods
# ![types](feature-selection-techniques-in-machine-learning3.png)

# %% [markdown]
# #### Forward Feature Selection

# %%
pip install mlxtend
# Out:
# Requirement already satisfied: mlxtend in c:\users\ajantha\anaconda3\lib\site-packages (0.23.4)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: scipy>=1.2.1 in c:\users\ajantha\anaconda3\lib\site-packages (from mlxtend) (1.13.1)
# Requirement already satisfied: numpy>=1.16.2 in c:\users\ajantha\anaconda3\lib\site-packages (from mlxtend) (1.26.4)
# Requirement already satisfied: pandas>=0.24.2 in c:\users\ajantha\anaconda3\lib\site-packages (from mlxtend) (2.2.2)
# Requirement already satisfied: scikit-learn>=1.3.1 in c:\users\ajantha\anaconda3\lib\site-packages (from mlxtend) (1.6.1)
# Requirement already satisfied: matplotlib>=3.0.0 in c:\users\ajantha\anaconda3\lib\site-packages (from mlxtend) (3.8.4)
# Requirement already satisfied: joblib>=0.13.2 in c:\users\ajantha\anaconda3\lib\site-packages (from mlxtend) (1.4.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ajantha\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\ajantha\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ajantha\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\ajantha\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\ajantha\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (23.2)
# Requirement already satisfied: pillow>=8 in c:\users\ajantha\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\ajantha\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ajantha\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ajantha\anaconda3\lib\site-packages (from pandas>=0.24.2->mlxtend) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\ajantha\anaconda3\lib\site-packages (from pandas>=0.24.2->mlxtend) (2023.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\ajantha\anaconda3\lib\site-packages (from scikit-learn>=1.3.1->mlxtend) (3.6.0)
# Requirement already satisfied: six>=1.5 in c:\users\ajantha\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.0.0->mlxtend) (1.16.0)

# %%
from mlxtend.feature_selection import SequentialFeatureSelector

# %%
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression()
ss=SequentialFeatureSelector(lr,k_features=3,n_jobs=-1,forward=True)

# %%
ss.fit(X,y)
# Out:
# SequentialFeatureSelector(estimator=LogisticRegression(), k_features=(3, 3),
#                           n_jobs=-1, scoring='accuracy')

# %%
ss.k_feature_names_
# Out:
# ('sepal_length', 'petal_length', 'petal_width')

# %% [markdown]
# #### Backword Feature Elilmination

# %%
be=SequentialFeatureSelector(lr,k_features=3)

# %%
be.fit(X,y)
# Out:
# SequentialFeatureSelector(estimator=LogisticRegression(), k_features=(3, 3),
#                           scoring='accuracy')

# %%
be.k_feature_names_
# Out:
# ('sepal_length', 'petal_length', 'petal_width')

# %% [markdown]
# ## Embeded methods
# ![types](feature-selection-techniques-in-machine-learning6.png)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
model=RandomForestClassifier()
model.fit(X,y)
# Out:
# RandomForestClassifier()

# %%
model.feature_importances_
# Out:
# array([0.11058791, 0.02555528, 0.43061786, 0.43323894])

# %% [markdown]
# ## How to choose a Feature Selection Method
# ![types](feature-selection-techniques-in-machine-learning7.png)
